# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## 2-title.png
# ![2-title.png](attachment:fd76d736-0954-4930-bcee-5f2590d4998e.png)

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## 3-title.png : ![3-title.png](attachment:c9419e70-37fe-4607-bf36-56b4548412e3.png)

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. C++
# 3. Java
# 4. R

# %% [markdown]
# ## 4-dslanguages.png :
# ![Screen Shot 2023-08-02 at 2.34.06 PM.png](attachment:f11be4d1-978e-45be-bbd7-bb42b3ef8f86.png)

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Seaborn
# 4. Scikit-learn

# %% [markdown]
# ### 5-dslibraries.png
# ![Screen Shot 2023-08-02 at 2.37.32 PM.png](attachment:fc210368-4bb1-4621-9fc9-7e6ccb4ebf79.png)

# %% [markdown]
# ### Data Science Tools
# | Data Science Tools |
# | --------------------- |
# | 1. Jupyter Notebooks |
# | 2. R Studio|
# | 3. VS Code |

# %% [markdown]
# ### 6-dstools.png
# ![Screen Shot 2023-08-02 at 2.48.01 PM.png](attachment:16e94cbe-2bcb-4ee8-b248-e2dd86f849c6.png)

# %%
# addition
2+3
# Out:
# 5

# %% [markdown]
# ### 7-introarithmetic.png
# ![Screen Shot 2023-08-02 at 2.59.30 PM.png](attachment:035a8f08-57ca-4f45-82b6-647e21eef3d3.png)

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ### 8-multiplyandaddintegers.png
# ![Screen Shot 2023-08-02 at 3.03.24 PM.png](attachment:c85676bd-216a-48a2-a0c0-6fba6b50c77d.png)

# %%
### This will convert 200 minutes to hours by diving by 60
# Function to convert minutes to hours
# Function to convert minutes to hours and minutes
def minutes_to_hours_and_minutes(minutes):
    hours = minutes // 60
    remaining_minutes = minutes % 60
    return hours, remaining_minutes

# Input
minutes = 200

# Convert minutes to hours and minutes
hours, remaining_minutes = minutes_to_hours_and_minutes(minutes)

# Display the result
print(f"{minutes} minutes is equal to {hours} hours and {remaining_minutes} minutes.")
# Out:
# 200 minutes is equal to 3 hours and 20 minutes.

# %% [markdown]
# ### 9-hourstominutes.png
# ![Screen Shot 2023-08-02 at 3.09.27 PM 1.png](attachment:520206bf-a62a-4ce4-a220-eab4b59153e8.png)

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science: In this notebook, we explored some of the most commonly used programming languages in the field of Data Science, such as Python, R, and Julia.
#
# - Understand the basics of Jupyter Notebooks: We learned about the Jupyter Notebook environment and its features, including running code cells, creating Markdown cells, and visualizing data.
#
# - We have learned how to add pictures from our system in jupiter notebook.

# %% [markdown]
# ### 10-objectives.png
# ![Screen Shot 2023-08-02 at 3.15.20 PM.png](attachment:0ff9d846-89c2-4421-a322-8dadf1d8fda9.png)

# %% [markdown]
# ## Author -
# **Aaryan Rana**

# %% [markdown]
# ### 11-authordetails.png
# ![Screen Shot 2023-08-02 at 3.17.23 PM.png](attachment:96139b70-dd9b-4ece-94aa-849975edd363.png)
